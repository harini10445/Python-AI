# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dropout,Dense

# %%
dataset= pd.read_csv('GOOG.csv')
dataset.head(2)
# Out:
#   symbol                       date   close    high     low    open   volume  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.12  716.48  1306065
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.31  719.00  1214517
#
#    adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  splitFactor
# 0    718.27   722.47  713.12   716.48    1306065      0.0          1.0
# 1    718.92   722.98  717.31   719.00    1214517      0.0          1.0

# %%
dataset.drop("date",axis=1,inplace=True)

# %%
dataset
# Out:
#      symbol    close      high        low     open   volume  adjClose  \
# 0      GOOG   718.27   722.470   713.1200   716.48  1306065    718.27
# 1      GOOG   718.92   722.980   717.3100   719.00  1214517    718.92
# 2      GOOG   710.36   716.650   703.2600   714.91  1982471    710.36
# 3      GOOG   691.72   708.820   688.4515   708.65  3402357    691.72
# 4      GOOG   693.71   702.480   693.4100   698.77  2082538    693.71
# ...     ...      ...       ...        ...      ...      ...       ...
# 1253   GOOG  2466.09  2468.000  2441.0725  2451.32  1192453   2466.09
# 1254   GOOG  2482.85  2494.495  2468.2400  2479.90  1253253   2482.85
# 1255   GOOG  2491.40  2505.000  2487.3300  2499.50  1006337   2491.40
# 1256   GOOG  2521.60  2523.260  2494.0000  2494.01  1561733   2521.60
# 1257   GOOG  2513.93  2526.990  2498.2900  2524.92  1262309   2513.93
#
#        adjHigh     adjLow  adjOpen  adjVolume  divCash  splitFactor
# 0      722.470   713.1200   716.48    1306065      0.0          1.0
# 1      722.980   717.3100   719.00    1214517      0.0          1.0
# 2      716.650   703.2600   714.91    1982471      0.0          1.0
# 3      708.820   688.4515   708.65    3402357      0.0          1.0
# 4      702.480   693.4100   698.77    2082538      0.0          1.0
# ...        ...        ...      ...        ...      ...          ...
# 1253  2468.000  2441.0725  2451.32    1192453      0.0          1.0
# 1254  2494.495  2468.2400  2479.90    1253253      0.0          1.0
# 1255  2505.000  2487.3300  2499.50    1006337      0.0          1.0
# 1256  2523.260  2494.0000  2494.01    1561733      0.0          1.0
# 1257  2526.990  2498.2900  2524.92    1262309      0.0          1.0
#
# [1258 rows x 13 columns]

# %%
training_set = dataset.iloc[:, 1:2].values

sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

X_train = []
y_train = []

for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

print(regressor.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 60, 50)            20200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 60, 50)            20200
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0027
# Epoch 2/100
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0027
# Epoch 3/100
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0031
# Epoch 4/100
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0023
# Epoch 5/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0023
# Epoch 6/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0021
# Epoch 7/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0020
# Epoch 8/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0026
# Epoch 9/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0020
# Epoch 10/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0020
# Epoch 11/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0017
# Epoch 12/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0017
# Epoch 13/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0018
# Epoch 14/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0018
# Epoch 15/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0017
# Epoch 16/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0015
# Epoch 17/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0016
# Epoch 18/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0018
# Epoch 19/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0015
# Epoch 20/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0015
# Epoch 21/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0014
# Epoch 22/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0017
# Epoch 23/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0016
# Epoch 24/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0013
# Epoch 25/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0015
# Epoch 26/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0013
# Epoch 27/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0013
# Epoch 28/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0013
# Epoch 29/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0013
# Epoch 30/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0013
# Epoch 31/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0012
# Epoch 32/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0014
# Epoch 33/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0015
# Epoch 34/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0013
# Epoch 35/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0012
# Epoch 36/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0012
# Epoch 37/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0011
# Epoch 38/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0013
# Epoch 39/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0011
# Epoch 40/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0011
# Epoch 41/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0011
# Epoch 42/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0012
# Epoch 43/100
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0011
# Epoch 44/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0012
# Epoch 45/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0013
# Epoch 46/100
# 38/38 [==============================] - 2s 58ms/step - loss: 9.8678e-04
# Epoch 47/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0011
# Epoch 48/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0011
# Epoch 49/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0011
# Epoch 50/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0010
# Epoch 51/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0010
# Epoch 52/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0010
# Epoch 53/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0010
# Epoch 54/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0012
# Epoch 55/100
# 38/38 [==============================] - 2s 59ms/step - loss: 9.8503e-04
# Epoch 56/100
# 38/38 [==============================] - 2s 59ms/step - loss: 9.3179e-04
# Epoch 57/100
# 38/38 [==============================] - 2s 59ms/step - loss: 8.4834e-04
# Epoch 58/100
# 38/38 [==============================] - 2s 60ms/step - loss: 9.2450e-04
# Epoch 59/100
# 38/38 [==============================] - 2s 61ms/step - loss: 9.4445e-04
# Epoch 60/100
# 38/38 [==============================] - 2s 60ms/step - loss: 7.9600e-04
# Epoch 61/100
# 38/38 [==============================] - 2s 64ms/step - loss: 8.8404e-04
# Epoch 62/100
# 38/38 [==============================] - 2s 62ms/step - loss: 9.7979e-04
# Epoch 63/100
# 38/38 [==============================] - 2s 63ms/step - loss: 9.0603e-04
# Epoch 64/100
# 38/38 [==============================] - 2s 62ms/step - loss: 9.4858e-04
# Epoch 65/100
# 38/38 [==============================] - 2s 62ms/step - loss: 9.3493e-04
# Epoch 66/100
# 38/38 [==============================] - 3s 70ms/step - loss: 9.3631e-04
# Epoch 67/100
# 38/38 [==============================] - 3s 67ms/step - loss: 9.1331e-04
# Epoch 68/100
# 38/38 [==============================] - 4s 104ms/step - loss: 9.3046e-04
# Epoch 69/100
# 38/38 [==============================] - 5s 144ms/step - loss: 9.0849e-04
# Epoch 70/100
# 38/38 [==============================] - 5s 137ms/step - loss: 8.8604e-04
# Epoch 71/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0010
# Epoch 72/100
# 38/38 [==============================] - 2s 58ms/step - loss: 9.3820e-04
# Epoch 73/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0011
# Epoch 74/100
# 38/38 [==============================] - 2s 59ms/step - loss: 8.5420e-04
# Epoch 75/100
# 38/38 [==============================] - 3s 78ms/step - loss: 9.1215e-04
# Epoch 76/100
# 38/38 [==============================] - 6s 147ms/step - loss: 9.9529e-04
# Epoch 77/100
# 38/38 [==============================] - 5s 139ms/step - loss: 8.9023e-04
# Epoch 78/100
# 38/38 [==============================] - 2s 57ms/step - loss: 8.6198e-04
# Epoch 79/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0013
# Epoch 80/100
# 38/38 [==============================] - 2s 59ms/step - loss: 8.6017e-04
# Epoch 81/100
# 38/38 [==============================] - 2s 59ms/step - loss: 8.1471e-04
# Epoch 82/100
# 38/38 [==============================] - 3s 66ms/step - loss: 9.3567e-04
# Epoch 83/100
# 38/38 [==============================] - 2s 64ms/step - loss: 8.3580e-04
# Epoch 84/100
# 38/38 [==============================] - 2s 64ms/step - loss: 8.3761e-04
# Epoch 85/100
# 38/38 [==============================] - 2s 63ms/step - loss: 8.5763e-04
# Epoch 86/100
# 38/38 [==============================] - 2s 63ms/step - loss: 7.2621e-04
# Epoch 87/100
# 38/38 [==============================] - 2s 59ms/step - loss: 7.9356e-04
# Epoch 88/100
# 38/38 [==============================] - 2s 61ms/step - loss: 8.0526e-04
# Epoch 89/100
# 38/38 [==============================] - 2s 62ms/step - loss: 7.5455e-04
# Epoch 90/100
# 38/38 [==============================] - 2s 61ms/step - loss: 8.2071e-04
# Epoch 91/100
# 38/38 [==============================] - 2s 61ms/step - loss: 9.3176e-04
# Epoch 92/100
# 38/38 [==============================] - 2s 63ms/step - loss: 6.6915e-04
# Epoch 93/100
# 38/38 [==============================] - 2s 61ms/step - loss: 8.2675e-04
# Epoch 94/100
# 38/38 [==============================] - 2s 62ms/step - loss: 7.2656e-04
# Epoch 95/100
# 38/38 [==============================] - 2s 62ms/step - loss: 8.5426e-04
# Epoch 96/100
# 38/38 [==============================] - 2s 62ms/step - loss: 7.6884e-04
# Epoch 97/100
# 38/38 [==============================] - 2s 63ms/step - loss: 7.5635e-04
# Epoch 98/100
# 38/38 [==============================] - 2s 61ms/step - loss: 8.1458e-04
# Epoch 99/100
# 38/38 [==============================] - 2s 61ms/step - loss: 8.1036e-04
# Epoch 100/100
# 38/38 [==============================] - 2s 61ms/step - loss: 6.8604e-04

# %%
dataset_test = pd.read_csv('GOOG.csv')
real_stock_price = dataset_test.iloc[60:80, 1].values.flatten()

# %%
dataset_total = pd.concat((dataset['open'], dataset_test['open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values

inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

X_test = []

for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
real_stock_price = real_stock_price.flatten()

plt.plot(real_stock_price, color='red', label='Real Google Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
